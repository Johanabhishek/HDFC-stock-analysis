# %%
import pandas as pd
import numpy as np

df=pd.read_csv('HDFC.CSV')
df
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 0     2000-01-03   HDFC     EQ      271.75   293.50   293.50   293.50
# 1     2000-01-04   HDFC     EQ      293.50   317.00   317.00   297.00
# 2     2000-01-05   HDFC     EQ      304.05   290.00   303.90   285.00
# 3     2000-01-06   HDFC     EQ      292.80   301.00   314.00   295.00
# 4     2000-01-07   HDFC     EQ      296.45   290.00   296.35   281.00
# ...          ...    ...    ...         ...      ...      ...      ...
# 5301  2021-04-26   HDFC     EQ     2497.35  2500.00  2534.10  2483.20
# 5302  2021-04-27   HDFC     EQ     2509.80  2494.15  2526.80  2486.25
# 5303  2021-04-28   HDFC     EQ     2518.40  2516.10  2609.00  2508.30
# 5304  2021-04-29   HDFC     EQ     2577.00  2590.90  2628.00  2533.00
# 5305  2021-04-30   HDFC     EQ     2538.85  2503.10  2525.00  2411.10
#
#          Last    Close     VWAP   Volume      Turnover    Trades  \
# ...

# %%
df.head()
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03   HDFC     EQ      271.75  293.5  293.50  293.5  293.5  293.50
# 1  2000-01-04   HDFC     EQ      293.50  317.0  317.00  297.0  304.0  304.05
# 2  2000-01-05   HDFC     EQ      304.05  290.0  303.90  285.0  295.0  292.80
# 3  2000-01-06   HDFC     EQ      292.80  301.0  314.00  295.0  296.0  296.45
# 4  2000-01-07   HDFC     EQ      296.45  290.0  296.35  281.0  287.1  286.55
#
#      VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  293.50   22744  6.675364e+11     NaN                 NaN          NaN
# 1  303.62  255251  7.749972e+12     NaN                 NaN          NaN
# 2  294.53  269087  7.925368e+12     NaN                 NaN          NaN
# 3  300.14  305916  9.181669e+12     NaN                 NaN          NaN
# 4  288.80  197039  5.690480e+12     NaN                 NaN          NaN

# %%
df.tail()
# Out:
#             Date Symbol Series  Prev Close     Open    High      Low     Last  \
# 5301  2021-04-26   HDFC     EQ     2497.35  2500.00  2534.1  2483.20  2502.00
# 5302  2021-04-27   HDFC     EQ     2509.80  2494.15  2526.8  2486.25  2514.00
# 5303  2021-04-28   HDFC     EQ     2518.40  2516.10  2609.0  2508.30  2575.00
# 5304  2021-04-29   HDFC     EQ     2577.00  2590.90  2628.0  2533.00  2539.70
# 5305  2021-04-30   HDFC     EQ     2538.85  2503.10  2525.0  2411.10  2433.25
#
#         Close     VWAP   Volume      Turnover    Trades  Deliverable Volume  \
# 5301  2509.80  2508.07  3916088  9.821805e+14  121028.0           2440395.0
# 5302  2518.40  2509.18  2040799  5.120730e+14  102250.0           1040749.0
# 5303  2577.00  2574.21  3407461  8.771527e+14  117425.0           1815110.0
# 5304  2538.85  2569.65  3005468  7.722995e+14  132826.0           1472924.0
# 5305  2420.10  2445.94  6024595  1.473581e+15  224454.0           3839105.0
#
#       %Deliverble
# 5301       0.6232
# ...

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1283.666114  1284.393074  1304.269732  1263.297842  1283.885017
# std     709.395090   709.703665   721.308080   697.450309   709.250204
# min     271.750000   284.000000   290.500000   273.250000   282.850000
# 25%     668.650000   669.712500   677.512500   660.000000   669.000000
# 50%    1136.275000  1135.400000  1156.725000  1119.000000  1135.000000
# 75%    1811.475000  1813.812500  1835.000000  1783.075000  1812.000000
# max    3180.150000  3148.000000  3262.000000  3100.550000  3178.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1284.071005  1283.664578  1.848187e+06  2.620759e+14  102159.051303
# std     709.430515   709.109622  2.991387e+06  3.607844e+14   57948.603200
# ...

# %%
description_df = pd.DataFrame(data=df.describe())
print(description_df)
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1283.666114  1284.393074  1304.269732  1263.297842  1283.885017
# std     709.395090   709.703665   721.308080   697.450309   709.250204
# min     271.750000   284.000000   290.500000   273.250000   282.850000
# 25%     668.650000   669.712500   677.512500   660.000000   669.000000
# 50%    1136.275000  1135.400000  1156.725000  1119.000000  1135.000000
# 75%    1811.475000  1813.812500  1835.000000  1783.075000  1812.000000
# max    3180.150000  3148.000000  3262.000000  3100.550000  3178.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1284.071005  1283.664578  1.848187e+06  2.620759e+14  102159.051303
# std     709.430515   709.109622  2.991387e+06  3.607844e+14   57948.603200
# ...

# %%
#df.fillna(value={'ma_7': 0, 'ma_10': 0, 'daily_return': 0}, inplace=True)

# %%
df.isna().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %%
df.drop(['Trades', 'Deliverable Volume', '%Deliverble'], axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %% [markdown]
# **Feature Engineering**

# %%
df['next_close'] = df['Close'].shift(-1)
df.dropna(inplace=True)#removes the last row with nun

# %%
df['ma_7'] = df['Close'].rolling(window=7).mean()
df['ma_10'] = df['Close'].rolling(window=10).mean()

# %%
df['daily_return'] = df['Close'].pct_change()

# %%
df['daily_return']
# Out:
# 0            NaN
# 1       0.035945
# 2      -0.037000
# 3       0.012466
# 4      -0.033395
#           ...
# 5300    0.007118
# 5301    0.004985
# 5302    0.003427
# 5303    0.023269
# 5304   -0.014804
# Name: daily_return, Length: 5305, dtype: float64

# %%
df.drop(['Date', 'Open', 'High', 'Low', 'Volume', 'Symbol','Series'], axis=1, inplace=True)

# %% [markdown]
# **build and train the model**

# %%
from sklearn.model_selection import train_test_split
x=df.drop('next_close', axis=1)
y = df['next_close']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#       Prev Close     Last    Close     VWAP      Turnover         ma_7  \
# 4280     1365.40  1365.50  1367.70  1367.10  3.185993e+14  1377.121429
# 2284     1498.55  1424.00  1433.60  1451.14  2.129582e+14  1504.542857
# 5095     1769.35  1742.75  1741.15  1738.95  6.867005e+14  1796.950000
# 602       594.90   594.95   594.80   594.05  5.921774e+12   605.314286
# 1215      629.85   649.25   649.65   645.05  2.684612e+13   645.178571
# ...          ...      ...      ...      ...           ...          ...
# 3092      635.30   639.00   641.25   645.49  1.112409e+14   638.200000
# 3772     1288.00  1323.35  1328.60  1323.53  5.002989e+14  1271.771429
# 5191     2272.10  2318.00  2324.30  2307.35  1.669440e+15  2172.400000
# 5226     2558.65  2565.00  2568.75  2574.95  5.289220e+14  2499.864286
# 860       372.30   367.30   367.65   369.17  8.618266e+11   371.042857
#
#          ma_10  daily_return
# 4280  1379.535      0.001684
# 2284  1477.025     -0.043342
# ...

# %%
from sklearn.impute import SimpleImputer

# Impute missing values with the mean
imputer = SimpleImputer(strategy='mean')
x_train = imputer.fit_transform(x_train)

# %%
imputer = SimpleImputer(strategy='mean')
x_test = imputer.fit_transform(x_test)

# %%
y_train
# Out:
# 4280    1371.50
# 2284    1362.35
# 5095    1754.65
# 602      600.30
# 1215     668.95
#          ...
# 3092     642.60
# 3772    1353.45
# 5191    2332.10
# 5226    2578.50
# 860      387.10
# Name: next_close, Length: 4244, dtype: float64

# %%
df.isna().sum()
# Out:
# Prev Close      0
# Last            0
# Close           0
# VWAP            0
# Turnover        0
# next_close      0
# ma_7            6
# ma_10           9
# daily_return    1
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9976488907675855

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_pred = model.predict(x_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred, squared=False))
# Out:
# MAE: 20.410006480726302
# RMSE: 33.99688963254796
# C:\Users\johan\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# **Data visualization**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %%
model.score(x_test, y_test)
# Out:
# 0.9976488907675855

# %%
model.score(x_train, y_train)
# Out:
# 0.9949008404827328
